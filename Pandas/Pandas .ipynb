# %% [markdown]
# **Practice pandas**

# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "Name" : ['nabil','nur','muttakin','hamza'],
    "Age" : [23,22,24,25],
    "Marks" : [98,95,90,92], 

}

# %%
df = pd.DataFrame(dict1)

# %%
 df
# Out:
#        Name  Age  Marks
# 0     nabil   23     98
# 1       nur   22     95
# 2  muttakin   24     90
# 3     hamza   25     92

# %%
df.to_csv('marks.csv')

# %%
df.to_csv('marks_index_false.csv',index = False)

# %%
df.head(2)
# Out:
#     Name  Age  Marks
# 0  nabil   23     98
# 1    nur   22     95

# %%
df.tail(2)
# Out:
#        Name  Age  Marks
# 2  muttakin   24     90
# 3     hamza   25     92

# %%
df.describe()
# Out:
#              Age  Marks
# count   4.000000   4.00
# mean   23.500000  93.75
# std     1.290994   3.50
# min    22.000000  90.00
# 25%    22.750000  91.50
# 50%    23.500000  93.50
# 75%    24.250000  95.75
# max    25.000000  98.00

# %%
nabil = pd.read_csv('Nabil.csv')

# %%
nabil
# Out:
#    Train no.  Speed     City
# 0       1234    200  Rajshai
# 1       5678    160    Dhaka
# 2       9876    120  Rangpur
# 3       5432    200   Natore

# %%
nabil['Speed']
# Out:
# 0    200
# 1    160
# 2    120
# 3    200
# Name: Speed, dtype: int64

# %%
nabil ['Speed'][0] = 200
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_17652\1473208933.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nabil ['Speed'][0] = 200

# %%
nabil
# Out:
#    Train no.  Speed     City
# 0       1234    200  Rajshai
# 1       5678    160    Dhaka
# 2       9876    120  Rangpur
# 3       5432    200   Natore

# %%
nabil.to_csv('Nabil1.csv')

# %%
nabil.index = ['first','second','third','fourth']

# %%
nabil
# Out:
#         Train no.  Speed     City
# first        1234    200  Rajshai
# second       5678    160    Dhaka
# third        9876    120  Rangpur
# fourth       5432    200   Natore

# %%
series = pd.Series(np.random.rand(30))

# %%
series
# Out:
# 0     0.968990
# 1     0.234693
# 2     0.448846
# 3     0.937268
# 4     0.581497
# 5     0.210512
# 6     0.723091
# 7     0.541350
# 8     0.901204
# 9     0.943988
# 10    0.081717
# 11    0.749751
# 12    0.810306
# 13    0.924320
# 14    0.724204
# 15    0.270970
# 16    0.625236
# 17    0.828540
# 18    0.327576
# 19    0.085952
# 20    0.981761
# 21    0.258306
# 22    0.392717
# 23    0.484711
# 24    0.658916
# 25    0.616213
# 26    0.371459
# 27    0.961670
# 28    0.547110
# 29    0.383233
# dtype: float64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(300,5), index = np.arange(300))

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.989668  0.867332  0.623287  0.156894  0.605986
# 1  0.597390  0.009439  0.083130  0.370361  0.768411
# 2  0.692559  0.731989  0.992647  0.961078  0.521103
# 3  0.456320  0.928188  0.412932  0.540862  0.050758
# 4  0.027991  0.958759  0.747017  0.286046  0.173778

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  300.000000  300.000000  300.000000  300.000000  300.000000
# mean     0.498825    0.510001    0.512120    0.492617    0.519785
# std      0.282461    0.279527    0.286199    0.299436    0.287640
# min      0.003731    0.003943    0.003327    0.000526    0.003695
# 25%      0.276162    0.284269    0.293669    0.223454    0.262622
# 50%      0.498612    0.513253    0.513168    0.477794    0.524555
# 75%      0.736402    0.749217    0.752664    0.754598    0.756715
# max      0.991433    0.997049    0.997890    0.998512    0.997904

# %%
newdf[0][0] = 'nabil'
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_
# %%
type(newdf[0])
# Out:
# pandas.core.series.Series

# %%
newdf2 = newdf

# %%
newdf2[0][0] = 812

# %%
newdf2.head()
# Out:
#           0         1         2         3         4
# 0       812  0.867332  0.623287  0.156894  0.605986
# 1   0.59739  0.009439  0.083130  0.370361  0.768411
# 2  0.692559  0.731989  0.992647  0.961078  0.521103
# 3   0.45632  0.928188  0.412932  0.540862  0.050758
# 4  0.027991  0.958759  0.747017  0.286046  0.173778

# %%
newdf2 = newdf.copy()

# %%
newdf2[0][0] = 954
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_17652\4134114712.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   newdf2[0][0] = 954
# C:\Users\Asus\AppData\Local\Temp\ipykernel_17652\4134114712.py:1: SettingWithCopyWarning:
# ...

# %%
newdf
# Out:
#             0         1         2         3         4
# 0         812  0.867332  0.623287  0.156894  0.605986
# 1     0.59739  0.009439  0.083130  0.370361  0.768411
# 2    0.692559  0.731989  0.992647  0.961078  0.521103
# 3     0.45632  0.928188  0.412932  0.540862  0.050758
# 4    0.027991  0.958759  0.747017  0.286046  0.173778
# ..        ...       ...       ...       ...       ...
# 295  0.785327  0.419881  0.969102  0.763735  0.931906
# 296  0.910794  0.450235  0.575865  0.684012  0.909465
# 297  0.663385  0.871220  0.991310  0.717627  0.520806
# 298   0.46485  0.692992  0.361205  0.898385  0.519512
# 299  0.499495  0.164479  0.557219  0.059450  0.588032
#
# [300 rows x 5 columns]

# %%
#when we want a value change in array then we use loc
newdf.loc[0,1] = 743

# %%
newdf.head()
# Out:
#           0           1         2         3         4
# 0       812  743.000000  0.623287  0.156894  0.605986
# 1   0.59739    0.009439  0.083130  0.370361  0.768411
# 2  0.692559    0.731989  0.992647  0.961078  0.521103
# 3   0.45632    0.928188  0.412932  0.540862  0.050758
# 4  0.027991    0.958759  0.747017  0.286046  0.173778

# %%
newdf.loc[0,5]=987

# %%
newdf.head()
# Out:
#           0           1         2         3         4      5
# 0       812  743.000000  0.623287  0.156894  0.605986  987.0
# 1   0.59739    0.009439  0.083130  0.370361  0.768411    NaN
# 2  0.692559    0.731989  0.992647  0.961078  0.521103    NaN
# 3   0.45632    0.928188  0.412932  0.540862  0.050758    NaN
# 4  0.027991    0.958759  0.747017  0.286046  0.173778    NaN

# %%
newdf.drop(5,axis = 1, inplace = True)

# %%
newdf
# Out:
#             0           1         2         3         4
# 0         812  743.000000  0.623287  0.156894  0.605986
# 1     0.59739    0.009439  0.083130  0.370361  0.768411
# 2    0.692559    0.731989  0.992647  0.961078  0.521103
# 3     0.45632    0.928188  0.412932  0.540862  0.050758
# 4    0.027991    0.958759  0.747017  0.286046  0.173778
# ..        ...         ...       ...       ...       ...
# 295  0.785327    0.419881  0.969102  0.763735  0.931906
# 296  0.910794    0.450235  0.575865  0.684012  0.909465
# 297  0.663385    0.871220  0.991310  0.717627  0.520806
# 298   0.46485    0.692992  0.361205  0.898385  0.519512
# 299  0.499495    0.164479  0.557219  0.059450  0.588032
#
# [300 rows x 5 columns]

# %%
newdf.loc[[1,2],[1,2]]
# Out:
#           1         2
# 1  0.009439  0.083130
# 2  0.731989  0.992647

# %%
newdf.loc[:,[0,2]]
# Out:
#             0         2
# 0         812  0.623287
# 1     0.59739  0.083130
# 2    0.692559  0.992647
# 3     0.45632  0.412932
# 4    0.027991  0.747017
# ..        ...       ...
# 295  0.785327  0.969102
# 296  0.910794  0.575865
# 297  0.663385  0.991310
# 298   0.46485  0.361205
# 299  0.499495  0.557219
#
# [300 rows x 2 columns]

# %%
newdf.loc[[1,2], :]
# Out:
# 4    0.027991    0.958759  0.747017  0.286046  0.173778
# ..        ...         ...       ...       ...       ...
# 295  0.785327    0.419881  0.969102  0.763735  0.931906
# 296  0.910794    0.450235  0.575865  0.684012  0.909465
# 297  0.663385    0.871220  0.991310  0.717627  0.520806
# 298   0.46485    0.692992  0.361205  0.898385  0.519512
# 299  0.499495    0.164479  0.557219  0.059450  0.588032
#
# [300 rows x 5 columns]

# %%
newdf.head(2)
# Out:
#          0           1         2         3         4
# 0      812  743.000000  0.623287  0.156894  0.605986
# 1  0.59739    0.009439  0.083130  0.370361  0.768411

# %%
newdf.iloc[0,4]
# Out:
# np.float64(0.6059859542188013)

# %%
newdf.iloc[[0,5],[1,2]]
# Out:
#             1         2
# 0  743.000000  0.623287
# 5    0.314342  0.780497

# %%
newdf.head(3)
# Out:
#           0           1         2         3         4
# 0       812  743.000000  0.623287  0.156894  0.605986
# 1   0.59739    0.009439  0.083130  0.370361  0.768411
# 2  0.692559    0.731989  0.992647  0.961078  0.521103

# %%
newdf.drop([0])
# Out:
#             0         1         2         3         4
# 1     0.59739  0.009439  0.083130  0.370361  0.768411
# 2    0.692559  0.731989  0.992647  0.961078  0.521103
# 3     0.45632  0.928188  0.412932  0.540862  0.050758
# 4    0.027991  0.958759  0.747017  0.286046  0.173778
# 5    0.979831  0.314342  0.780497  0.423659  0.132322
# ..        ...       ...       ...       ...       ...
# 295  0.785327  0.419881  0.969102  0.763735  0.931906
# 296  0.910794  0.450235  0.575865  0.684012  0.909465
# 297  0.663385  0.871220  0.991310  0.717627  0.520806
# 298   0.46485  0.692992  0.361205  0.898385  0.519512
# 299  0.499495  0.164479  0.557219  0.059450  0.588032
#
# [299 rows x 5 columns]

# %%
newdf.drop(['0','2'], axis = 1, inplace = True)
# when we permanently drop something then use inplace = true

# %%
newdf
# Out:
#               1         3         4
# 0    743.000000  0.156894  0.605986
# 1      0.009439  0.370361  0.768411
# 2      0.731989  0.961078  0.521103
# 3      0.928188  0.540862  0.050758
# 4      0.958759  0.286046  0.173778
# ..          ...       ...       ...
# 295    0.419881  0.763735  0.931906
# 296    0.450235  0.684012  0.909465
# 297    0.871220  0.717627  0.520806
# 298    0.692992  0.898385  0.519512
# 299    0.164479  0.059450  0.588032
#
# [300 rows x 3 columns]

# %%
newdf.drop([1,2], axis = 0, inplace=True)

# %%
newdf
# Out:
#               1         3         4
# 0    743.000000  0.156894  0.605986
# 3      0.928188  0.540862  0.050758
# 4      0.958759  0.286046  0.173778
# 5      0.314342  0.423659  0.132322
# 6      0.596320  0.749010  0.542396
# ..          ...       ...       ...
# 295    0.419881  0.763735  0.931906
# 296    0.450235  0.684012  0.909465
# 297    0.871220  0.717627  0.520806
# 298    0.692992  0.898385  0.519512
# 299    0.164479  0.059450  0.588032
#
# [298 rows x 3 columns]

# %%
newdf.reset_index(drop = True,inplace=True)

# %%
newdf
# Out:
#               1         3         4
# 0    743.000000  0.156894  0.605986
# 1      0.928188  0.540862  0.050758
# 2      0.958759  0.286046  0.173778
# 3      0.314342  0.423659  0.132322
# 4      0.596320  0.749010  0.542396
# ..          ...       ...       ...
# 293    0.419881  0.763735  0.931906
# 294    0.450235  0.684012  0.909465
# 295    0.871220  0.717627  0.520806
# 296    0.692992  0.898385  0.519512
# 297    0.164479  0.059450  0.588032
#
# [298 rows x 3 columns]

# %%
newdf2
# Out:
#             0         1         2         3         4
# 0         954  0.867332  0.623287  0.156894  0.605986
# 1     0.59739  0.009439  0.083130  0.370361  0.768411
# 2    0.692559  0.731989  0.992647  0.961078  0.521103
# 3     0.45632  0.928188  0.412932  0.540862  0.050758
# 4    0.027991  0.958759  0.747017  0.286046  0.173778
# ..        ...       ...       ...       ...       ...
# 295  0.785327  0.419881  0.969102  0.763735  0.931906
# 296  0.910794  0.450235  0.575865  0.684012  0.909465
# 297  0.663385  0.871220  0.991310  0.717627  0.520806
# 298   0.46485  0.692992  0.361205  0.898385  0.519512
# 299  0.499495  0.164479  0.557219  0.059450  0.588032
#
# [300 rows x 5 columns]

# %%
newdf['1'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 293    False
# 294    False
# 295    False
# 296    False
# 297    False
# Name: 1, Length: 298, dtype: bool

# %%
newdf['3'] = None

# %%
newdf
# Out:
#               1     3         4
# 0    743.000000  None  0.605986
# 1      0.928188  None  0.050758
# 2      0.958759  None  0.173778
# 3      0.314342  None  0.132322
# 4      0.596320  None  0.542396
# ..          ...   ...       ...
# 293    0.419881  None  0.931906
# 294    0.450235  None  0.909465
# 295    0.871220  None  0.520806
# 296    0.692992  None  0.519512
# 297    0.164479  None  0.588032
#
# [298 rows x 3 columns]

# %%
newdf['3'].isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 293    True
# 294    True
# 295    True
# 296    True
# 297    True
# Name: 3, Length: 298, dtype: bool

# %%
newdf.loc[:,['1']] = None
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_17652\1726293708.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'None' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   newdf.loc[:,['1']] = None

# %%
newdf.loc[:,['3']]=40

# %%
newdf.head(
    
)
# Out:
#       1   3         4
# 0  None  40  0.605986
# 1  None  40  0.050758
# 2  None  40  0.173778
# 3  None  40  0.132322
# 4  None  40  0.542396

# %%
df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman'],
                   "toy": [np.nan, 'Batmobile', 'Bullwhip'],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"),
                            pd.NaT]})

# %%
df
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna()
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
df.dropna(axis=1)
# Out:
#        name
# 0    Alfred
# 1    Batman
# 2  Catwoman

# %%
df.dropna(how='all')
#until all off are not nan than its not drop
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   toy     2 non-null      object
#  2   born    1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 204.0+ bytes

# %%
df['name'].value_counts(dropna=True)
# Out:
# name
# Alfred      1
# Batman      1
# Catwoman    1
# Name: count, dtype: int64

# %%
df.isnull()
# Out:
#     name    toy   born
# 0  False   True   True
# 1  False  False  False
# 2  False  False   True

# %%
df.notnull()
# Out:
#    name    toy   born
# 0  True  False  False
# 1  True   True   True
# 2  True   True  False

# %%
data = pd.read_excel('Nabil2.xlsx',sheet_name='Sheet1')

# %%
data
# Out:
#    Unnamed: 0  Train no. s1  Speed s1  City s1
# 0           0            40       200  Rajshai
# 1           1          6764       160    Dhaka
# 2           2          5432       120  Rangpur
# 3           3          1234       200   Natore

# %%
data.iloc[0,0] =40

# %%
data
# Out:
#    Unnamed: 0  Train no. s1  Speed s1  City s1
# 0          40            40       200  Rajshai
# 1           1          6764       160    Dhaka
# 2           2          5432       120  Rangpur
# 3           3          1234       200   Natore

# %%
data.to_excel('Nabil2.xlsx',sheet_name='Sheet1')
#this way can not work multiple sheet

# %%
data
# Out:
#    Unnamed: 0  Train no. s1  Speed s1  City s1
# 0          40            40       200  Rajshai
# 1           1          6764       160    Dhaka
# 2           2          5432       120  Rangpur
# 3           3          1234       200   Natore

# %%
data2 = pd.read_excel('data.xlsx', sheet_name='Sheet1')

# %%
data2.iloc[0, 0] = 50

# %%
df2 = data2.copy()

# %%
with pd.ExcelWriter('yyyyy.xlsx') as writer:
    data2.to_excel(writer, sheet_name='Nabil', index=False)  # data2 কে 'Nabil' শীটে
    df2.to_excel(writer, sheet_name='Sheet1', index=False)

# %%
data2
# Out:
#    Train no. s1  Speed s1  City s1
# 0            50       200  Rajshai
# 1          6764       160    Dhaka
# 2          5432       120  Rangpur
# 3          1234       200   Natore
